# %% [markdown]
# ![image.png](attachment:image.png)

# %%
gross = int (input())
buah = gross * 144
print(buah)
# Out:
# 1440

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
phi= 3.14
r = int (input())
kell = 2 * phi * r
print(kell)
# Out:
# 125.60000000000001

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bilangan = 0

while bilangan < 12:
    bilangan += 4
    print(bilangan)
# Out:
# 4
# 8
# 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int (input ("Input nilai : "))
if a > 70:
    print("Anda Lulus")
    
else:
    print("Anda HER")
# Out:
# Anda Lulus

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bil = 1
while bil < 10:
    print(bil)
    bil = bil + 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
